# %%
# Alle Variablen löschen ohne zu fragen.
# Hierdurch werden Seiteneffekte vermieden.
# %reset -f

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from   mpl_toolkits import mplot3d
import math as mth

# %matplotlib notebook

# %%
# Definition einer Funktion z(x,y) = 10*sin(sqrt(x**2+y**2))+2x
# = Funktionsgebirge über x-y-Ebene

# Hier geht es los .........
def MyFunction(x, y):
    z=10*mth.sin(mth.sqrt(x**2+y**2))+2*x
    return z
MyFunction2 = np.vectorize(MyFunction)

# %%
# Definition des Gradienten grad(z(x,y)) = [dz/dx, dz/dy] 
# von MyFunftion

# Hier geht es los .........
def MyGradient(x, y):
    dx=(10*x/mth.sqrt(x**2+y**2))*mth.cos(mth.sqrt(x**2+y**2))+2
    dy=(10*y/mth.sqrt(x**2+y**2))*mth.cos(mth.sqrt(x**2+y**2))
    return np.array([dx, dy])

# %%
# Erzeugen der x- und y-Werte eines zweidimensionalen
# Gitters von -6 bis +6 mit 100 Schritten unterteilt
# --> XGrid, YGrid
# Hinweis: (linspace, meshgrid)  
xgrid = np.linspace(-6, 6, 100)
ygrid = np.linspace(-6, 6, 100)
XGrid, YGrid = np.meshgrid(xgrid, ygrid)


print('xgrid.shape =', xgrid.shape)
print('XGrid.shape =', XGrid.shape)

#print()
#print('XGrid =',XGrid)
#print()
#print('YGrid =',YGrid)


#TEST
#ergebnis = np.zeros((100,2))
#print(ergebnis)
#x,y = MyGradient2(xgrid,ygrid)
#print(x)
#print(y)
# Out:
# xgrid.shape = (100,)
# XGrid.shape = (100, 100)

# %%
# Berechnung der Funktionswerte z für alle 
# Werte XGrid, YGrid

# Hier geht es los .........
#Z = MyFunction(XGrid, YGrid)
Z = MyFunction2(XGrid, YGrid)
#Z = MyFunction(4, 5)
print('Z=', Z)
# Out:
# Z= [[-3.92738909 -3.21163209 -2.56195025 ... 20.46835278 20.30351942
#   20.07261091]
#  [-3.45405633 -2.79651773 -2.20867094 ... 20.82163209 20.71863379
#   20.54594367]
#  [-3.04679874 -2.45109518 -1.92832071 ... 21.10198232 21.06405633
#   20.95320126]
#  ...
#  [-3.04679874 -2.45109518 -1.92832071 ... 21.10198232 21.06405633
#   20.95320126]
#  [-3.45405633 -2.79651773 -2.20867094 ... 20.82163209 20.71863379
#   20.54594367]
#  [-3.92738909 -3.21163209 -2.56195025 ... 20.46835278 20.30351942
#   20.07261091]]

# %%
# Anzeige der Funktion (je höher der Funktionswert, desto roter ....)
fig = plt.figure(1, figsize=(5, 4))
#fig = plt.figure(1)
plt.imshow(Z, origin='lower', extent=[-6,6,-6,6], cmap='coolwarm')
cb = plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# Anzeige der Funktion z(x,y) als Surfaceplot
fig = plt.figure(3, figsize=(5, 5))
ax  = plt.axes(projection='3d')
ax.plot_surface(XGrid, YGrid, Z, cmap='coolwarm')
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
# Suche eines lokalen Minimums durch Gradientenabstieg
n     = 40     # Anzahl der Schritte
eta   = 0.25   # Schrittweitenfaktor
alpha = 0.3    # Momentumfaktor

# Koordinaten des Gradientenabstiegs-Pfades 
xVek      = np.zeros((n,2))

# Startpunkt der Iteration
xVek[0]   = np.array([[1.8,0.5]])

#plt.plot(xGrad,yGrad)
# Iteration
for i in range(0, n-1):
    xVek[i+1] = xVek[i]-eta*MyGradient(xVek[i][0],xVek[i][1])+ alpha*(xVek[i]-xVek[i-1])
    
    #xVekT = np.transpose(xVek)
print(xVek)
# Out:
# [[ 1.8         0.5       ]
#  [ 2.54576489  0.8460458 ]
#  [ 4.39643782  1.65671649]
#  [ 4.48475981  1.91239839]
#  [ 3.63785712  1.82987745]
#  [ 4.21796337  2.47622518]
#  [ 3.50874316  2.44513502]
#  [ 3.66165327  3.03907103]
#  [ 3.11878495  3.14359896]
#  [ 2.94958644  3.67254706]
#  [ 2.40197483  3.83515101]
#  [ 1.98457815  4.2781279 ]
#  [ 1.35552979  4.40276609]
#  [ 0.74440837  4.6921802 ]
#  [ 0.04600453  4.684031  ]
#  [-0.66282599  4.75190374]
#  [-1.34597501  4.56077442]
#  [-2.02060611  4.40071936]
#  [-2.58771619  4.0580754 ]
#  [-3.12294077  3.74371781]
#  [-3.52383097  3.33811483]
#  [-3.88811019  2.9739374 ]
#  [-4.13665463  2.5887619 ]
#  [-4.35784492  2.25206469]
#  [-4.49826501  1.93093809]
#  [-4.62277381  1.65533254]
#  [-4.69755477  1.40701224]
#  [-4.76450826  1.19609048]
#  [-4.80296404  1.01190465]
#  [-4.83805827  0.85627039]
#  [-4.85744147  0.72265412]
#  [-4.87559223  0.61001818]
#  [-4.88524865  0.51419592]
#  [-4.89457624  0.4334987 ]
#  [-4.89935163  0.36518106]
#  [-4.9041326   0.30766704]
#  [-4.90648155  0.25910207]
#  [-4.9089308   0.21822065]
#  [-4.91008088  0.18374778]
#  [-4.91133637  0.15472872]]

# %%
# Funktion (imshow) mit Pfad des Gradientenabstiegs

# Überlagerung eines Bildes (imshow) und
# eines Pfades

# Anzeige der Funktion (je höher der Funktionswert, desto roter ....)
fig = plt.figure(2, figsize=(5, 4))
plt.imshow(Z, origin='lower', extent=[-6,6,-6,6], cmap='coolwarm')
cb = plt.colorbar()

# Anzeigen des Pfades
plt.plot(xVek[:,0], xVek[:,1],lw=0.7, c='black')
# Anzeigen des Pfades
#plt.plot(xVekT[0,:], xVekT[1,:],lw=0.7, c='black')
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# # Beispiel eines Gradientenabstiegs
#
# ![grafik.png](attachment:grafik.png)
